# %%
import pandas as pd
from pycaret.classification import *

# %%
df = pd.read_csv('data/temp3.csv')
df
# Out:
#                                               Question  Category
# 0    ammaː kokis 4k saːdana viʈa akkaː kokis 3k saː...         0
# 1    veralu ɡeɖi 3ka haː amba ɡeɖi 2 ka mila ræ.46....         0
# 2    28 ,63, 74 ,56, 45 ,81 mehi æti 9 ɡunaːkaːra ɡ...         1
# 3    2021 d͡ʒanavaːri 2 senasuraːdaː nam 2022 d͡ʒan...         0
# 4    taːppajak bædiːmaʈa pedareːruvan 3n denekuʈa d...         0
# 5    vaʈʈakkaː ɡeɖijaʈa 4kg 50g komaɖu ɡeɖija 1kg 2...         0
# 6    ɡamanakin 1/5ka dura 4km veː. ema ɡamaneː mulu...         0
# 7    raʈaːva anuva histæn puravanna 12,5,7     16,9...         2
# 8    ɡaːmiɳiː viduhaleː 4056k iɡenuma labaji. iːʈa ...         0
# 9    hataɭis tun dahas aʈasijavisipaha jana saŋk‍ja...         1
# 10   maː laɡa rupijal 150.00 k æta in rupijal 40k m...         0
# 11   peti 5 mal 5ka æti peti ɡanana roːma saŋk‍jaːv...         1
# 12   paːsalaka 1 siʈa 5 tek panti 5k æta ehi sæːma ...         0
# ...

# %%
cat_features = ['Question']
experiment = setup(df, target='Category', categorical_features=cat_features)
# Out:
# <style type="text/css">
# #T_7a228_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7a228">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a228_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7a228_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a228_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a228_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_7a228_row0_col1" class="data row0 col1" >548</td>
#     </tr>
#     <tr>
#       <th id="T_7a228_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7a228_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7a228_row1_col1" class="data row1 col1" >Category</td>
#     </tr>
#     <tr>
#       <th id="T_7a228_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_ed5e0 th {
#   text-align: left;
# }
# ...

# %%
top3 = compare_models(n_select = 3)
# Out:
# <style type="text/css">
# #T_b006b th {
#   text-align: left;
# }
# ...

# %%
save_model(top3[2], model_name='new_train_models/Gradient_Boosting_Classifier')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=['Question'],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='Category',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  n...
#                                              learning_rate=0.1, loss='deviance',
#                                              max_depth=3, max_features=None,
# ...
